# %%
import csv
import pandas as pd
import os

# %%
df = pd.read_csv('C:\\Users\\Anchana en Robert\\Documents\\Bootcamp-project\\backend\\backup\\manipulated_data_enhanced_3.csv')

# %%
df.sort_values(by='date', ascending=False, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
new_df = pd.DataFrame()


for row in df.index:
    for row2 in df.index:
        if df["genre"][row] == df["genre"][row2] and df["date_index"][row] != df["date_index"][row2]:
            new_df.append( df[    ["genre","date","date_index","count"]   ].iloc[row]  , df[["genre", "date"]].iloc[row2]  )
            
            break
print(new_df)
# Out:
# C:\Users\Anchana en Robert\AppData\Local\Temp\ipykernel_7228\2220058901.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df.append( df[    ["genre","date","date_index","count"]   ].iloc[row]  , df[["genre", "date"]].iloc[row2]  )
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [87], in <cell line: 4>()
#       5     for row2 in df.index:
#       6         if df["genre"][row] == df["genre"][row2] and df["date_index"][row] != df["date_index"][row2]:
# ----> 7             new_df.append( df[    ["genre","date","date_index","count"]   ].iloc[row]  , df[["genre", "date"]].iloc[row2]  )
#       9             break
#      10 print(new_df)
#
# ...

# %%
for row in df.index:
# Out:
#             date                      genre  rank_aggregate  count    id  \
# 0     2021-12-01                baroque pop        0.204336      1  7675
# 1     2021-12-01             permanent wave        0.492585      2  7646
# 2     2021-12-01  canadian contemporary r&b        0.501187      1  7644
# 3     2021-12-01                    europop        0.518817      2  7643
# 4     2021-12-01                 a cappella        0.544826      2  7642
# ...          ...                        ...             ...    ...   ...
# 7670  2012-01-01           children's music        0.258397      1    32
# 7671  2012-01-01               gangster rap        0.264677      1    31
# 7672  2012-01-01          conscious hip hop        0.271677      1    30
# 7673  2012-01-01                    pop r&b        0.295782      1    29
# 7674  2012-01-01       contemporary country        8.612198     30     1
#
#                                               image_url  date_index
# ...
